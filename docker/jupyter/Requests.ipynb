# %% [markdown]
# # WIS2.0 in a box

# %% [markdown]
# Import Requirements

# %%
import requests
import json

oapi = "http://pygeoapi/pygeoapi" # jupyter is run through docker
#oapi = http://localhost:8999/pygeoapi # jupyter is run on host machine

def pretty_print(input):
    print(json.dumps(input, indent=2))

# %% [markdown]
# ## Station

# %%
url = f"{oapi}/collections/stations/items"

response = requests.get(url).json()

pretty_print(response["features"][0])
# Out:
# {
#   "id": "0-454-2-AWSBALAKA",
#   "type": "Feature",
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       34.966666,
#       -14.983333,
#       618
#     ]
#   },
#   "properties": {
#     "wigos_id": "0-454-2-AWSBALAKA",
#     "name": "BALAKA",
#     "url": "https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-454-2-AWSBALAKA",
#     "status": "operational",
#     "id": 91893
#   }
# }

# %% [markdown]
# ## Discovery Metadata

# %%
url = f"{oapi}/collections/discovery-metadata/items"

response = requests.get(url).json()

pretty_print(response["features"][0])
# Out:
# {
#   "id": "data.core.observations-surface-land.mw.FWCL.landFixed",
#   "type": "Feature",
#   "bbox": [
#     32.6881653175,
#     -16.8012997372,
#     35.7719047381,
#     -9.23059905359
#   ],
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           32.6881653175,
#           -16.8012997372
#         ],
#         [
#           32.6881653175,
#           -9.23059905359
#         ],
#         [
#           35.7719047381,
#           -9.23059905359
#         ],
#         [
#           35.7719047381,
#           -16.8012997372
#         ],
#         [
#           32.6881653175,
#           -16.8012997372
#         ]
#       ]
#     ]
#   },
#   "properties": {
#     "identifier": "data.core.observations-surface-land.mw.FWCL.landFixed",
#     "externalId": [
#       {
#         "scheme": "default",
#         "value": "data.core.observations-surface-land.mw.FWCL.landFixed"
#       }
#     ],
#     "title": "Surface weather observations (hourly)",
#     "description": "Surface weather observations (hourly)",
#     "themes": [
#       {
#         "concepts": [
#           "surface weather",
#           "temperature",
#           "observations"
#         ]
#       },
#       {
#         "concepts": [
#           "weatherObservations"
#         ],
#         "scheme": "https://github.com/wmo-im/wcmp-codelists/blob/main/codelists/WMO_CategoryCode.csv"
#       },
#       {
#         "concepts": [
#           "mw.malawi.weatherObservations.dataset_name"
#         ],
#         "scheme": "https://github.com/wmo-im/wcmp2-codelists/blob/main/codelists/topic_hierarchy.csv"
#       }
#     ],
#     "providers": [
#       {
#         "name": "Department of Climate Change and Meteorologial Services (DCCMS)",
#         "individual": "Firstname Lastname",
#         "positionName": "Position Name",
#         "contactInfo": {
#           "phone": {
#             "office": "+265-1-822-014"
#           },
#           "email": {
#             "office": "+265-1-822-215"
#           },
#           "address": {
#             "office": {
#               "deliveryPoint": "P.O. Box 1808",
#               "city": "Blantyre",
#               "administrativeArea": "Blantyre District",
#               "postalCode": "M3H 5T4",
#               "country": "Malawi"
#             },
#             "onlineResource": {
#               "href": "https://www.metmalawi.gov.mw"
#             }
#           },
#           "hoursOfService": "0700h - 1500h UTC",
#           "contactInstructions": "email",
#           "url": {
#             "rel": "canonical",
#             "type": "text/html",
#             "href": "https://www.metmalawi.gov.mw"
#           }
#         },
#         "roles": [
#           {
#             "name": "pointOfContact"
#           }
#         ]
#       },
#       {
#         "name": "Department of Climate Change and Meteorologial Services (DCCMS)",
#         "individual": "Firstname Lastname",
#         "positionName": "Position Name",
#         "contactInfo": {
#           "phone": {
#             "office": "+265-1-822-014"
#           },
#           "email": {
#             "office": "+265-1-822-215"
#           },
#           "address": {
#             "office": {
#               "deliveryPoint": "P.O. Box 1808",
#               "city": "Blantyre",
#               "administrativeArea": "Blantyre District",
#               "postalCode": "M3H 5T4",
#               "country": "Malawi"
#             },
#             "onlineResource": {
#               "href": "https://www.metmalawi.gov.mw"
#             }
#           },
#           "hoursOfService": "0700h - 1500h UTC",
#           "contactInstructions": "email",
#           "url": {
#             "rel": "canonical",
#             "type": "text/html",
#             "href": "https://www.metmalawi.gov.mw"
#           }
#         },
#         "roles": [
#           {
#             "name": "distributor"
#           }
#         ]
#       }
#     ],
#     "language": "en",
#     "type": "dataset",
#     "extent": {
#       "spatial": {
#         "bbox": [
#           [
#             32.6881653175,
#             -16.8012997372,
#             35.7719047381,
#             -9.23059905359
#           ]
#         ],
#         "crs": "http://www.opengis.net/def/crs/OGC/1.3/CRS84"
#       },
#       "temporal": {
#         "interval": [
#           "2021-11-29",
#           null
#         ],
#         "trs": "http://www.opengis.net/def/uom/ISO-8601/0/Gregorian",
#         "resolution": "P1H"
#       }
#     },
#     "created": "2021-11-29",
#     "rights": "WMO Unified Policy for the International Exchange of Earth System Data",
#     "_metadata-anytext": "Surface weather observations (hourly) Surface weather observations (hourly) surface weather temperature observations weatherObservations mw.malawi.weatherObservations.dataset_name",
#     "id": "data.core.observations-surface-land.mw.FWCL.landFixed"
#   },
#   "associations": [
#     {
#       "rel": "collection",
#       "href": "http://localhost:8999/pygeoapi/collections/data.core.observations-surface-land.mw.FWCL.landFixed",
#       "type": "OAFeat",
#       "title": "data.core.observations-surface-land.mw.FWCL.landFixed"
#     },
#     {
#       "rel": "collection",
#       "href": "mqtt://mosquitto/",
#       "type": "MQTT",
#       "title": "data.core.observations-surface-land.mw.FWCL.landFixed"
#     }
#   ],
#   "links": [
#     {
#       "url": "http://localhost:8999/pygeoapi/collections/discovery-metadata/data.core.observations-surface-land.mw.FWCL.landFixed",
#       "type": "OARec",
#       "name": "data.core.observations-surface-land.mw.FWCL.landFixed",
#       "description": "data.core.observations-surface-land.mw.FWCL.landFixed",
#       "function": "canonical"
#     }
#   ]
# }

# %% [markdown]
# ## Observations

# %%
url = f"{oapi}/collections/data.core.observations-surface-land.mw.FWCL.landFixed/items"

response = requests.get(url).json()

pretty_print(response['features'][0])
# Out:
# {
#   "id": "WIGOS_0-454-2-AWSNAMITAMBO_20210707T145500",
#   "conformsTo": [
#     "http://www.opengis.net/spec/ogcapi-features-1/1.0/req/geojson",
#     "http://www.wmo.int/spec/om-profile-1/-/req/geojson"
#   ],
#   "type": "Feature",
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       35.27,
#       -15.84,
#       806.0
#     ]
#   },
#   "properties": {
#     "identifier": "WIGOS_0-454-2-AWSNAMITAMBO_20210707T145500",
#     "phenomenonTime": "2021-07-07T14:55:00+00:00",
#     "resultTime": "2022-02-20T23:50:02+00:00",
#     "wmo:wigos_station_identifier": "0-454-2-AWSNAMITAMBO",
#     "metadata": [
#       {
#         "name": "height_of_station_above_ground_level",
#         "value": 806.0,
#         "units": "m"
#       }
#     ],
#     "observations": {
#       "air_pressure": {
#         "value": 93284.05,
#         "units": "Pa",
#         "metadata": [
#           {
#             "name": "sensor_height_above_mean_sea_level",
#             "value": 807.0,
#             "units": "m"
#           }
#         ]
#       },
#       "pressure_at_mean_sea_level": {
#         "value": 102745.5,
#         "units": "Pa",
#         "metadata": [
#           {
#             "name": "sensor_height_above_mean_sea_level",
#             "value": 807.0,
#             "units": "m"
#           }
#         ]
#       },
#       "change_of_air_pressure_over_past_3_hours": {
#         "value": null,
#         "units": "Pa",
#         "metadata": [
#           {
#             "name": "sensor_height_above_mean_sea_level",
#             "value": 807.0,
#             "units": "m"
#           }
#         ]
#       },
#       "characteristic_of_pressure_tendency": {
#         "value": 4.0,
#         "units": "CODE TABLE",
#         "metadata": [
#           {
#             "name": "sensor_height_above_mean_sea_level",
#             "value": 807.0,
#             "units": "m"
#           }
#         ]
#       },
#       "air_temperature": {
#         "value": 15.550000000000011,
#         "units": "Celsius",
#         "metadata": [
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "dew_point_temperature": {
#         "value": 13.650000000000034,
#         "units": "Celsius",
#         "metadata": [
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "relative_humidity": {
#         "value": 88.0,
#         "units": "%",
#         "metadata": [
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "duration_of_sunshine_1hr": {
#         "value": 0.0,
#         "units": "min",
#         "metadata": [
#           {
#             "name": "time_period",
#             "value": -1.0,
#             "units": "h"
#           }
#         ]
#       },
#       "duration_of_sunshine_24h": {
#         "value": 0.0,
#         "units": "min",
#         "metadata": [
#           {
#             "name": "time_period",
#             "value": -24.0,
#             "units": "h"
#           }
#         ]
#       },
#       "precipitation_amount_1h": {
#         "value": 0.0,
#         "units": "kg m-2",
#         "metadata": [
#           {
#             "name": "time_period",
#             "value": -1.0,
#             "units": "h"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "air_temperature_maximum": {
#         "value": 16.350000000000023,
#         "units": "Celsius",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "description": "maximum"
#           },
#           {
#             "name": "time_period_start",
#             "value": -24.0,
#             "units": "h"
#           },
#           {
#             "name": "time_period_end",
#             "value": 0.0,
#             "units": "h"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "air_temperature_minimum": {
#         "value": -3.75,
#         "units": "Celsius",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "description": "minimum"
#           },
#           {
#             "name": "time_period_start",
#             "value": -24.0,
#             "units": "h"
#           },
#           {
#             "name": "time_period_end",
#             "value": 0.0,
#             "units": "h"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 1.5,
#             "units": "m"
#           }
#         ]
#       },
#       "wind_from_direction": {
#         "value": 188.0,
#         "units": "deg",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "value": 2.0,
#             "units": "CODE TABLE"
#           },
#           {
#             "name": "time_period",
#             "value": -10.0,
#             "units": "min"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 2.0,
#             "units": "m"
#           },
#           {
#             "name": "wind_sensor_type",
#             "value": 0.0,
#             "units": "FLAG TABLE"
#           }
#         ]
#       },
#       "wind_speed": {
#         "value": 2.975,
#         "units": "m/s",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "value": 2.0,
#             "units": "CODE TABLE"
#           },
#           {
#             "name": "time_period",
#             "value": -10.0,
#             "units": "min"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 2.0,
#             "units": "m"
#           },
#           {
#             "name": "wind_sensor_type",
#             "value": 0.0,
#             "units": "FLAG TABLE"
#           }
#         ]
#       },
#       "wind_speed_maximum_gust": {
#         "value": 7.16,
#         "units": "m/s",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "value": null,
#             "units": "CODE TABLE"
#           },
#           {
#             "name": "time_period",
#             "value": null,
#             "units": "min"
#           },
#           {
#             "name": "sensor_height_above_local_ground",
#             "value": 2.0,
#             "units": "m"
#           },
#           {
#             "name": "wind_sensor_type",
#             "value": 0.0,
#             "units": "FLAG TABLE"
#           }
#         ]
#       },
#       "surface_downwelling_shortwave_flux_in_air_1h": {
#         "value": 0.02758914,
#         "units": "J m-2",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "description": "sum"
#           },
#           {
#             "name": "time_period",
#             "value": -1.0,
#             "units": "h"
#           }
#         ]
#       },
#       "surface_downwelling_shortwave_flux_in_air_24h": {
#         "value": 0.02758914,
#         "units": "J m-2",
#         "metadata": [
#           {
#             "name": "cell_methods",
#             "description": "sum"
#           },
#           {
#             "name": "time_period",
#             "value": -24.0,
#             "units": "h"
#           }
#         ]
#       }
#     },
#     "id": "WIGOS_0-454-2-AWSNAMITAMBO_20210707T145500"
#   }
# }
